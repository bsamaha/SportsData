# %%
import pandas as pd

# %%
df = pd.read_csv('modern_RAPTOR_by_player.csv')

# %%
is_2018 =  df['season']== 2018

# %%
currentStats = df[is_2018]

# %%
currentStats.sort_values(by='mp', ascending=False).head(20)
# Out:
#                 player_name  player_id  season  poss    mp  \
# 1407           LeBron James  jamesle01    2018  8026  3948
# 2685          Klay Thompson  thompkl01    2018  6908  3300
# 1274           Jrue Holiday  holidjr01    2018  6991  3275
# 1900        Khris Middleton  middlkh01    2018  6604  3257
# 236            Bradley Beal   bealbr01    2018  6513  3193
# 1130           James Harden  hardeja01    2018  6466  3172
# 2853      Russell Westbrook  westbru01    2018  6533  3149
# 2880         Andrew Wiggins  wiggian01    2018  6380  3143
# 992             Paul George  georgpa01    2018  6488  3142
# 809            Kevin Durant  duranke01    2018  6604  3132
# 2616           Jayson Tatum  tatumja01    2018  6289  3121
# 1073         Draymond Green  greendr01    2018  6552  3106
# 2501            Ben Simmons  simmobe01    2018  6558  3101
# 2711     Karl-Anthony Towns  townska01    2018  6182  3088
# 686           Anthony Davis  davisan02    2018  6612  3085
# ...
