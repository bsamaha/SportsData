# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('modern_RAPTOR_by_player.csv')

# %%
df
# Out:
#        player_name  player_id  season  poss    mp  raptor_box_offense  \
# 0     Alex Abrines  abrinal01    2017  2387  1135            0.745505
# 1     Alex Abrines  abrinal01    2018  2546  1244            0.317549
# 2     Alex Abrines  abrinal01    2019  1279   588           -3.215683
# 3       Quincy Acy    acyqu01    2014  1716   847           -1.716079
# 4       Quincy Acy    acyqu01    2015  2517  1287           -2.014956
# ...            ...        ...     ...   ...   ...                 ...
# 3004    Ante Zizic  zizican01    2018   498   237            1.436917
# 3005    Ante Zizic  zizican01    2019  2240  1082           -2.614802
# 3006   Ivica Zubac  zubaciv01    2017  1305   609           -3.320225
# 3007   Ivica Zubac  zubaciv01    2018   871   410           -2.581325
# 3008   Ivica Zubac  zubaciv01    2019  2345  1079           -2.336006
#
#       raptor_box_defense  raptor_box_total  raptor_onoff_offense  \
# ...

# %%
is_2018 =  df['season']== 2018
is_2019 =  df['season']== 2019

# %% [markdown]
# First we will parse all the players that played in 2019

# %%
currentStats = df[is_2019]

# %% [markdown]
# Next will only have players who have played over 40 min

# %%
topMinutes = currentStats[currentStats['mp'] > 40]

# %%
topMinutes #488 players
# Out:
#        player_name  player_id  season  poss    mp  raptor_box_offense  \
# 2     Alex Abrines  abrinal01    2019  1279   588           -3.215683
# 8       Quincy Acy    acyqu01    2019   278   123           -5.741317
# 9     Jaylen Adams  adamsja01    2019   952   428           -2.679920
# 17    Steven Adams  adamsst01    2019  6164  2828           -0.996033
# 19     Bam Adebayo  adebaba01    2019  3965  1913           -1.952989
# ...            ...        ...     ...   ...   ...                 ...
# 2988    Trae Young  youngtr01    2019  5516  2503            2.097204
# 2994   Cody Zeller  zelleco01    2019  2606  1243            0.023389
# 3000  Tyler Zeller  zellety01    2019   195    93           -0.904035
# 3005    Ante Zizic  zizican01    2019  2240  1082           -2.614802
# 3008   Ivica Zubac  zubaciv01    2019  2345  1079           -2.336006
#
#       raptor_box_defense  raptor_box_total  raptor_onoff_offense  \
# ...

# %%
top100 = topMinutes.sort_values(by='raptor_total', ascending=False).head(100)

# %%
top100
# Out:
#             player_name  player_id  season  poss    mp  raptor_box_offense  \
# 1131       James Harden  hardeja01    2019  6728  3291            9.959259
# 993         Paul George  georgpa01    2019  6608  3045            5.094191
# 1491       Nikola Jokic  jokicni01    2019  6219  3061            6.312656
# 669       Stephen Curry  curryst01    2019  6820  3177            7.356518
# 835         Joel Embiid  embiijo01    2019  5350  2488            2.324392
# ...                 ...        ...     ...   ...   ...                 ...
# 1269      Aaron Holiday  holidaa01    2019  1418   659           -0.778047
# 2108        David Nwaba  nwabada01    2019  2019   984           -0.059454
# 318   Bogdan Bogdanovic  bogdabo01    2019  4181  1947            2.159103
# 2756  Jarred Vanderbilt  vandeja01    2019   170    74           -7.997059
# 2400       Derrick Rose   rosede01    2019  3005  1392            2.811870
#
#       raptor_box_defense  raptor_box_total  raptor_onoff_offense  \
# ...

# %%
bestOffense = top100[top100['raptor_box_offense'] > 0]

# %%
bestOffense = bestOffense.head(5) #75players

# %%
import seaborn as sns
 
# Just switch x and y
sns.violinplot( y=df["poss"], x=df["season"] )
#sns.plt.show()
