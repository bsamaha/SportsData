# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('fide_historical.csv')

# %%
df.head(100)
# Out:
#    ranking_date  rank                   name title country  rating  games  \
# 0      27-07-00     1        Kasparov, Garry     g     RUS    2849     35
# 1      27-07-00     2      Kramnik, Vladimir     g     RUS    2770     23
# 2      27-07-00     3     Anand, Viswanathan     g     IND    2762     23
# 3      27-07-00     4  Morozevich, Alexander     g     RUS    2756     28
# 4      27-07-00     5         Adams, Michael     g     ENG    2755     38
# ..          ...   ...                    ...   ...     ...     ...    ...
# 95     27-07-00    96         Kuzmin, Alexey     g     RUS    2596     22
# 96     27-07-00    97      Lutz, Christopher     g     GER    2595     35
# 97     27-07-00    98     Minasian, Artashes     g     ARM    2595     29
# 98     27-07-00    99    Iordachescu, Viorel     g     MDA    2594     79
# 99     27-07-00   100     Fominyh, Alexander     g     RUS    2594     45
#
#     birth_year
# 0         1963
# 1         1975
# 2         1969
# ...
